# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.callbacks.hooks import *
from fastai.utils.mem import *


from PIL import Image
from numpy import array

import time

import cv2
import numpy as np

from torchvision.utils import save_image
import torch

# %%
# cap = cv2.VideoCapture("train.mp4")
cap = cv2.imread('videoFrames/frame0.jpg')

# %% [markdown]
# ### Resizes images to proper size

# %%
count = 20
while count < 20400:
    
    frame = cv2.imread(f'videoFrames/frame{count}.jpg')
    frame = cv2.resize(frame, (480, 360), interpolation=cv2.INTER_AREA)
    cv2.imwrite(f'videoFrames/frame{count}.jpg', frame)
    
    if count % 1000 == 0:
        print("count = ", count)
    
    count += 1

# %%
frame1 = cap
# prvs = cv2.cvtColor(frame1, cv2.COLOR_BGR2GRAY)
# hsv = np.zeros_like(frame1)
# hsv[..., 1] = 255

# %% [markdown]
# ## Optimal Flow Tests

# %%
plt.imshow(frame1)

# %%
cap = cv2.imread('videoFrames/frame0.jpg')
frame1 = cap
prvs = cv2.cvtColor(frame1, cv2.COLOR_BGR2GRAY)

# %%
# Empty List: this will contain all magAng objects; approx 20,400
magAngList = []

# %%
len(magAngList)
# Out:
# 0

# %%
count = 1
fileCount = 1

# %%
while(count < 20400):
    
    frame2 = cv2.imread(f'videoFrames/frame{count}.jpg')
    
    nxt = cv2.cvtColor(frame2,cv2.COLOR_BGR2GRAY)

    flow = cv2.calcOpticalFlowFarneback(prvs,nxt, None, 0.5, 3, 15, 3, 5, 1.2, 0)

    mag, ang = (flow[...,0], flow[...,1])
    
    magAng = np.stack([mag, ang])
    
    magAngList.append(magAng)
    
#     magAngImage = torch.from_numpy(magAng)
#     save_image(magAngImage, f'testImages/optFlow{count}.png')

    prvs = nxt
    count += 1
    if count % 1000 == 0 or count % 500 == 0:
        print("count = ", count)
        
    if count % 1000 == 0:
        np.save(f'tests/optFlowMat{fileCount}.npy', magAngList)
        magAngList.clear()
        fileCount += 1
        
        
    

cv2.destroyAllWindows()
# Out:
# count =  500
# count =  1000
# count =  1500
# count =  2000
# count =  2500
# count =  3000
# count =  3500
# count =  4000
# count =  4500
# count =  5000
# count =  5500
# count =  6000
# count =  6500
# count =  7000
# count =  7500
# count =  8000
# count =  8500
# count =  9000
# count =  9500
# count =  10000
# count =  10500
# count =  11000
# count =  11500
# count =  12000
# count =  12500
# count =  13000
# count =  13500
# count =  14000
# count =  14500
# count =  15000
# count =  15500
# count =  16000
# count =  16500
# count =  17000
# count =  17500
# count =  18000
# count =  18500
# count =  19000
# count =  19500
# count =  20000

# %%
count
# Out:
# 20400

# %%
fileCount
# Out:
# 21

# %%
len(magAngList)
# Out:
# 400

# %%
np.save('tests/optFlowMat22.npy', magAngList)

# %%
matrices = np.load('tests/optFlowMat20.npy')

# %%
len(matrices)
# Out:
# 1000

# %%
magAng.shape
# Out:
# (2, 360, 480)

# %%
type(matrices)
