# %%
from fastai.vision import *
from fastai.callbacks.hooks import *
from fastai.utils.mem import *
from fastai import *

# %%
train = open('/Users/christopher/Desktop/speed_challenge_2017 (1)/data/train.txt','r')
speeds = train.readlines()
train.close()

# %%
len(speeds)
# Out:
# 20400

# %%
spd = [] 
count = 0
while count < len(speeds):
    spd.append(float(speeds[count][:-2]))
    count += 1

spd
# Out:
# [28.10556,
#  28.10556,
#  28.10652,
#  28.1304,
#  28.10924,
#  28.08857,
#  28.03421,
#  28.01849,
#  27.98662,
#  28.01635,
#  27.98198,
#  27.97862,
#  28.03233,
#  27.96021,
#  27.93717,
#  27.94059,
#  27.90857,
#  27.8986,
#  27.85598,
#  27.79558,
#  27.85063,
#  27.83934,
#  27.82434,
#  27.7596,
#  27.83005,
#  27.76188,
#  27.69476,
#  27.7612,
#  27.69193,
#  27.66608,
#  27.72391,
#  27.63946,
#  27.61287,
#  27.63853,
#  27.60609,
#  27.5932,
#  27.57392,
#  27.56115,
#  27.55923,
#  27.52806,
#  27.52254,
#  27.53105,
#  27.49301,
#  27.4877,
#  27.44094,
#  27.43964,
#  27.4129,
#  27.40174,
#  27.396,
#  27.35751,
#  27.36564,
#  27.34763,
#  27.30212,
#  27.30983,
#  27.26627,
#  27.26606,
#  27.23809,
#  27.23903,
#  27.22743,
#  27.20983,
#  27.22482,
#  27.18166,
#  27.17009,
#  27.15459,
#  27.10411,
#  27.08135,
#  27.07187,
#  27.07326,
#  27.03933,
#  27.04149,
#  27.01814,
#  27.00955,
#  26.99624,
#  26.95483,
#  26.96857,
#  26.91307,
#  26.90346,
# ...

# %%
len(spd)
# Out:
# 20400

# %%
speed = spd

# %%
len(speed)
# Out:
# 20400
